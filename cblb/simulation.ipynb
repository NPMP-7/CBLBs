# %% [markdown]
# # Field-programmable biological circuits and configurable (bio)logic blocks for distributed biological computing

# %% [markdown]
# The file simulation.ipynb enables us to simulate implemented biological circuits and configurable (bio)logic blocks in a more organized manner.

# %% [markdown]
# We will simulate the following biological circuits and configurable (bio)logic blocks:
# * `run_ODE_AND_OR_NOT.py`: simulates the and or not gates that are implemented using ordinary differential equation (ODE),
# * `run_ode_model_clb.py`: description,
# * `run_ode_model_mux.py`: description,
# * `run_ode_model_not.py`: description,
# * `run_ode_model_toggle.py`: description,
# * `run_ode_model_yes.py`: description.

# %%
# %run run_ODE_AND_OR_NOT.py
# Out:
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ODE_AND_OR_NOT.py:124: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y[i,:] = r.integrate(r.t+dt)

# %% [markdown]
# Simulation of the file `run_ODE_AND_OR_NOT.py`.

# %%
# %run run_ode_model_clb.py
# Out:
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_clb.py:113: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y[i,:] = r.integrate(r.t+dt)

# %% [markdown]
# Simulation of the file `run_code_model_clb.py`.

# %%
# %run run_ode_model_mux_8bit.py
# Out:
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_mux_8bit.py:44: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y[i,:] = r.integrate(r.t+dt)

# %% [markdown]
# Simulation of `run_ode_model_mux_8bit.py`

# %%
# %run run_ode_model_not.py
# Out:
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_not.py:37: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y[i,:] = r.integrate(r.t+dt)

# %% [markdown]
# Simulation of the not gates `run_ode_model_not.py`.

# %%
# %run run_ode_model_toggle.py
# Out:
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_toggle.py:61: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y2[i,:] = r.integrate(r.t+dt)
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_toggle.py:82: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y3[i,:] = r.integrate(r.t+dt)
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_toggle.py:103: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y4[i,:] = r.integrate(r.t+dt)
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_toggle.py:124: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y5[i,:] = r.integrate(r.t+dt)
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_toggle.py:145: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y6[i,:] = r.integrate(r.t+dt)

# %% [markdown]
# Simulation of the toggle `run_ode_model_toggle.py`.

# %%
# %run run_ode_model_yes.py
# Out:
# C:\Users\filip\FRI\NPMP\CBLBs\cblb\run_ode_model_yes.py:34: ComplexWarning: Casting complex values to real discards the imaginary part
#   Y[i,:] = r.integrate(r.t+dt)

# %% [markdown]
# Simulation of the yes `run_ode_model_yes.py`.
